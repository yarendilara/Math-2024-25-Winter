# %% [markdown]
# ## Differential Equations: A Comprehensive Guide
#
# ### 1. Introduction to Differential Equations
#
# A differential equation is an equation that involves a function and its derivatives. These equations describe various physical, biological, and economic phenomena by modeling how a quantity changes with respect to another. The primary goal is to find a function that satisfies the given equation.
#
# Differential equations are categorized based on their order, linearity, and whether they have constant or variable coefficients.
#
# ### 2. First-Order Differential Equations
#
# A first-order differential equation involves only the first derivative of the function. These equations often appear in population dynamics, radioactive decay, and cooling processes. A common method for solving first-order differential equations is **separation of variables**.
#
# #### 2.1. Separation of Variables
# The method of separation of variables is applicable when the equation can be rewritten in the form:
#
# $$ \frac{dy}{dx} = f(x) g(y) $$
#
# By rewriting and integrating:
#
# $$ \int \frac{dy}{g(y)} = \int f(x) dx $$
#
# we obtain a solution in implicit form, which can often be solved explicitly for \( y \).
#
# #### 2.2. Integrating Factor Method
# For linear first-order equations of the form:
#
# $$ \frac{dy}{dx} + P(x)y = Q(x) $$
#
# we use an integrating factor:
#
# $$ \mu(x) = e^{\int P(x)dx} $$
#
# Multiplying the entire equation by \( \mu(x) \) allows it to be rewritten as an exact differential equation, which can then be integrated to find \( y(x) \).
#
# ### 3. Second-Order Differential Equations
#
# A second-order differential equation involves the second derivative of the function. These equations frequently appear in mechanics, wave motion, and electrical circuits.
#
# #### 3.1. Characteristic Equation Approach
# For linear equations with constant coefficients:
#
# $$ a y'' + b y' + c y = 0 $$
#
# we assume a solution of the form:
#
# $$ y = e^{rx} $$
#
# Substituting into the equation gives a characteristic equation:
#
# $$ ar^2 + br + c = 0 $$
#
# Solving for \( r \) provides the general solution, which can involve real or complex exponentials depending on the nature of the roots.
#
# #### 3.2. Homogeneous and Particular Solutions
# For inhomogeneous equations:
#
# $$ y'' + ay' + by = f(x) $$
#
# we find the **complementary solution** (solving the homogeneous part) and a **particular solution** using methods like **undetermined coefficients** or **variation of parameters**.
#
# ### 4. Second-Order Partial Differential Equations
#
# Partial differential equations (PDEs) involve multiple independent variables. A fundamental PDE is the **wave equation**:
#
# $$ \frac{\partial^2 u}{\partial t^2} - v^2 \frac{\partial^2 u}{\partial x^2} = 0 $$
#
# Solutions to the wave equation take the form:
#
# $$ u(x,t) = A \cos(\omega t + kx) $$
#
# where \( \omega \) and \( k \) relate to the wave speed and frequency.
#
# ### 5. Conclusion
#
# Differential equations are crucial in modeling real-world systems. Understanding different solution techniques, including separation of variables, the characteristic equation, and integrating factors, allows for solving various first- and second-order equations. The extension to partial differential equations provides further insight into wave propagation and dynamic systems.

# %% [markdown]
# ## 25. Differential Equations
#
# 1. Solve the following first-order ordinary differential equations:
#    - $y'(x)= y$
#    - $y'(x) = \frac{1}{2y(x)}$
#
# 2. Solve the first-order ordinary differential equations using the method of separation of variables for $x$ and $y=y(x)$:
#
#    - $\frac{dy}{dx} = \frac{x}{y}$
#    - $\frac{dy}{dx} = \frac{y}{x}$
#    - $\frac{dy}{dx} = xy$
#
# 3. Solve the second-order ordinary differential equations:
#
#    * $y''(x) + y'(x) = 0$, with boundary conditions $y(0) = 2$ and $y'(0) = -1$
#
#    * $y''(x) - y(x)= 0$, with boundary conditions $y(0) = 2$ and $y'(0) = 0$
#
#    * $\frac{d^2\,y(x)}{dx^2} = -\omega^2 y(x)$.
#
# 4. Check if the function $\psi(t, x) = A \cos(\omega t + kx)$ is a solution of the second-order partial differential equation (the so-called "wave equation"), where $v = \frac{\omega}{k} = \frac{2\pi / T}{2\pi / \lambda}$:
#
# $$
# \frac{\partial^2 \psi(t, x)}{\partial t^2} - v^2 \frac{\partial^2 \psi(t, x)}{\partial x^2} = 0.
# $$

# %% [markdown]
# ## 25. Differential Equationsexercise solvings of mine
#
#
# #### (a) $y'(x) = y$
# This is a separable differential equation:
#
# $$ \frac{dy}{dx} = y $$
#
# Rearrange:
#
# $$ \frac{dy}{y} = dx $$
#
# Integrate both sides:
#
# $$ \ln |y| = x + C $$
#
# Solve for $y$:
#
# $$ y = C e^x $$
#
# #### (b) $y'(x) = \frac{1}{2y(x)}$
# Rearrange:
#
# $$ 2y dy = dx $$
#
# Integrate both sides:
#
# $$ \int 2y \, dy = \int dx $$
#
# $$ y^2 = x + C $$
#
# Solve for $y$:
#
# $$ y = \pm\sqrt{x + C} $$
#
# ### 2. Solve the first-order ordinary differential equations using separation of variables
#
# #### (a) $\frac{dy}{dx} = \frac{x}{y}$
# Rearrange:
#
# $$ y \, dy = x \, dx $$
#
# Integrate:
#
# $$ \int y \, dy = \int x \, dx $$
#
# $$ \frac{y^2}{2} = \frac{x^2}{2} + C $$
#
# $$ y^2 = x^2 + C $$
#
# $$ y = \pm\sqrt{x^2 + C} $$
#
# #### (b) $\frac{dy}{dx} = \frac{y}{x}$
# Rearrange:
#
# $$ \frac{dy}{y} = \frac{dx}{x} $$
#
# Integrate:
#
# $$ \ln |y| = \ln |x| + C $$
#
# $$ y = Cx $$
#
# #### (c) $\frac{dy}{dx} = xy$
# Rearrange:
#
# $$ \frac{dy}{y} = x \, dx $$
#
# Integrate:
#
# $$ \ln |y| = \frac{x^2}{2} + C $$
#
# $$ y = e^C e^{x^2/2} = C' e^{x^2/2} $$
#
# ### 3. Solve the second-order ordinary differential equations
#
# #### (a) $y''(x) + y'(x) = 0$
# The characteristic equation is:
#
# $$ r^2 + r = 0 $$
#
# $$ r(r + 1) = 0 \Rightarrow r = 0, -1 $$
#
# General solution:
#
# $$ y(x) = C_1 + C_2 e^{-x} $$
#
# Applying boundary conditions $y(0) = 2$ and $y'(0) = -1$, we find:
#
# $$ y(x) = 1 + e^{-x} $$
#
# #### (b) $y''(x) - y(x) = 0$
# The characteristic equation is:
#
# $$ r^2 - 1 = 0 $$
#
# $$ r = \pm 1 $$
#
# General solution:
#
# $$ y(x) = C_1 e^x + C_2 e^{-x} $$
#
# Applying boundary conditions $y(0) = 2$ and $y'(0) = 0$, we find:
#
# $$ y(x) = e^x + e^{-x} $$
#
# #### (c) $\frac{d^2 y}{dx^2} = -\omega^2 y(x)$
# The characteristic equation:
#
# $$ r^2 + \omega^2 = 0 $$
#
# $$ r = \pm i\omega $$
#
# General solution:
#
# $$ y(x) = C_1 \cos(\omega x) + C_2 \sin(\omega x) $$
#
# ### 4. Verify if $\psi(t, x) = A \cos(\omega t + kx)$ satisfies the wave equation
#
# The wave equation:
#
# $$ \frac{\partial^2 \psi}{\partial t^2} - v^2 \frac{\partial^2 \psi}{\partial x^2} = 0 $$
#
# Computing second derivatives:
#
# $$ \frac{\partial \psi}{\partial t} = -A \omega \sin(\omega t + kx) $$
#
# $$ \frac{\partial^2 \psi}{\partial t^2} = -A \omega^2 \cos(\omega t + kx) $$
#
# $$ \frac{\partial \psi}{\partial x} = -A k \sin(\omega t + kx) $$
#
# $$ \frac{\partial^2 \psi}{\partial x^2} = -A k^2 \cos(\omega t + kx) $$
#
# Substituting:
#
# $$ - A \omega^2 \cos(\omega t + kx) - v^2 (- A k^2 \cos(\omega t + kx)) = 0 $$
#
# $$ - A \omega^2 + v^2 A k^2 = 0 $$
#
# Since $ v = \frac{\omega}{k} $, we have $ v^2 = \frac{\omega^2}{k^2} $, so:
#
# $$ \omega^2 - \frac{\omega^2}{k^2} k^2 = 0 $$
#
# $$ \omega^2 - \omega^2 = 0 $$
#
# Thus, $\psi(t, x)$ satisfies the wave equation.
